# %%
# list csv files in ../out dir and print the number of rows in each file
import os
import csv

out_dir = '../Skud'
for file in os.listdir(out_dir):
    if file.endswith('.csv'):
        with open(os.path.join(out_dir, file), 'r') as f:
            reader = csv.reader(f)
            data = list(reader)
            print(f'{file}: {len(data)} rows')
# Out:
# skud1.csv: 1994 rows
# skud10.csv: 2340 rows
# skud11.csv: 2398 rows
# skud12.csv: 111 rows
# skud13.csv: 3857 rows
# skud14.csv: 561 rows
# skud15.csv: 674 rows
# skud16.csv: 3988 rows
# skud17.csv: 767 rows
# skud18.csv: 3307 rows
# skud19.csv: 3450 rows
# skud2.csv: 1925 rows
# skud20.csv: 3422 rows
# skud21.csv: 3935 rows
# skud22.csv: 1654 rows
# skud23.csv: 3973 rows
# skud24.csv: 1600 rows
# skud25.csv: 1053 rows
# skud26.csv: 1434 rows
# skud27.csv: 370 rows
# skud28.csv: 3974 rows
# skud29.csv: 3974 rows
# skud3.csv: 2678 rows
# skud30.csv: 3972 rows
# skud31.csv: 1071 rows
# skud32.csv: 3798 rows
# skud33.csv: 3972 rows
# skud34.csv: 3979 rows
# skud35.csv: 715 rows
# skud36.csv: 3972 rows
# skud37.csv: 1286 rows
# skud38.csv: 3948 rows
# skud39.csv: 3483 rows
# skud4.csv: 255 rows
# skud40.csv: 3967 rows
# skud41.csv: 2181 rows
# skud42.csv: 3026 rows
# skud43.csv: 3968 rows
# skud44.csv: 3972 rows
# skud45.csv: 3966 rows
# skud46.csv: 3968 rows
# skud47.csv: 3972 rows
# skud48.csv: 3975 rows
# skud49.csv: 2055 rows
# skud5.csv: 1077 rows
# skud50.csv: 1583 rows
# skud51.csv: 3391 rows
# skud52.csv: 567 rows
# skud53.csv: 2505 rows
# skud54.csv: 3093 rows
# skud55.csv: 3303 rows
# skud56.csv: 1831 rows
# skud57.csv: 229 rows
# skud58.csv: 3972 rows
# skud59.csv: 458 rows
# skud6.csv: 2565 rows
# skud60.csv: 2699 rows
# skud61.csv: 932 rows
# skud62.csv: 3913 rows
# skud63.csv: 3603 rows
# skud64.csv: 306 rows
# skud7.csv: 3066 rows
# skud8.csv: 3126 rows
# skud9.csv: 110 rows

# %%
#read this file into a panda and print header
import pandas as pd
df = pd.read_csv('../Skud/skud1.csv')
print(df.head())
# Out:
#    timestamp  accX  accY  accZ
# 0  808208010 -1.02  0.09 -0.12
# 1  808209952 -1.02  0.09 -0.12
# 2  808211952 -1.02  0.09 -0.12
# 3  808213950 -1.02  0.09 -0.12
# 4  808215950 -1.02  0.09 -0.12

# %%
import matplotlib.pyplot as plt

#plot df, first column is timestamp, next 3 columns are x, y, z
plt.plot(df.iloc[:, 0], df.iloc[:, 1])
plt.plot(df.iloc[:, 0], df.iloc[:, 2])
plt.plot(df.iloc[:, 0], df.iloc[:, 3])
plt.show()

# %%
#function for loading and plotting a csv file title of plot is first part of filename untill first '.', and samplerate (1/dt) dt is distance between first two timestamps in milliseconds
def plot_csv(file):
    df = pd.read_csv(file)
    title = file.split('.')[0]
    dt = df.iloc[11, 0] - df.iloc[10, 0]
    plt.plot(df.iloc[:, 0], df.iloc[:, 1])
    plt.plot(df.iloc[:, 0], df.iloc[:, 2])
    plt.plot(df.iloc[:, 0], df.iloc[:, 3])
    plt.title(f'{title} samplerate: {1000/dt:.2f} Hz')
    plt.show()

# %%
# we need another way to caculate dt, because the first two timestamps are not always the same, duration

# %%
plot_csv('../out/cross1.csv')
